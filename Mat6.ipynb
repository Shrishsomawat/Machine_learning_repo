# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp=[140,600,300,410,250]
exp_labels=["rent","food","phone","car_petrol","aish"]
plt.axis="equal"
plt.pie(exp,labels=exp_labels,autopct='%0.2f%%',shadow=True,explode=[0,0,0,0,.4])
plt.show()
