# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,3,5,7,9,11,13,15]
y=[20,42,54,46,38,18,42,54]

# %%
plt.xlabel('day')
plt.ylabel('temp')
plt.title('weather data')
plt.plot(x,y,color="olive",linewidth=4,linestyle="dotted")
