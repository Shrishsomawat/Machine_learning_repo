# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[23,34,45,67,78,45,56]

# %%
plt.xlabel("day")
plt.ylabel("temp")
plt.title("weather graph")
plt.plot(x,y,'r',alpha=0.5)
